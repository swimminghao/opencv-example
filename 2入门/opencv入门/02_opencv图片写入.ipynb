# %%
import cv2 
# 1 文件的读取 2 封装格式解析 3 数据解码 4 数据加载
img = cv2.imread('/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/2入门/opencv入门/image0.JPG', 1)
import matplotlib.pyplot as plt
img_rgb = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('Image')
plt.axis('off')
plt.show()
# jpg png  1 文件头 2 文件数据

# 1.14M 130k

# %%
import cv2
img = cv2.imread('/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/Users/xh/workspaces/jupyter/opencv-example/2入门/opencv入门/image0.JPG', 1)
cv2.imwrite('image2.jpg', img) # 1 name 2 data
# Out:
# True
