# %%
#placehold
import tensorflow as tf
data1 = tf.compat.v1.placeholder(tf.float32)
data2 = tf.compat.v1.placeholder(tf.float32)
dataAdd = tf.add(data1,data2)
print(dataAdd)
# print(dataAdd,feed_dict={data1:6,data2:2})
    # 1 dataAdd 2 data (feed_dict = {1:6,2:2})
print('end!')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 #placehold
#       2 import tensorflow as tf
# ----> 3 data1 = tf.compat.v1.placeholder(tf.float32)
#       4 data2 = tf.compat.v1.placeholder(tf.float32)
#       5 dataAdd = tf.add(data1,data2)
#
# File ~/anaconda3/envs/tf_cuda11.8/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:3340, in placeholder(dtype, shape, name)
#    3293 """Inserts a placeholder for a tensor that will be always fed.
#    3294
#    3295 **Important**: This tensor will produce an error if evaluated. Its value must
#    (...)
#    3337 @end_compatibility
#    3338 """
#    3339 if context.executing_eagerly():
# -> 3340   raise RuntimeError("tf.placeholder() is not compatible with "
#    3341                      "eager execution.")
#    3343 return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#
# ...

# %%
#类比 数组 M行N列 []   内部[]  [里面 列数据]   [] 中括号整体 行数
#[[6,6]] [[6,6]]
import tensorflow as tf
data1 = tf.constant([[6,6]])
data2 = tf.constant([[2],
                     [2]])
data3 = tf.constant([[3,3]])
data4 = tf.constant([[1,2],
                     [3,4],
                     [5,6]])
print(data4.shape)# 维度
print(data4) #打印整体
print(data4[0])# 打印某一行
print(data4[0,1])# 1 1  MN = 0 32 = M012 N01
print(data4[:,0])#MN 列
# Out:
# (3, 2)
# tf.Tensor(
# [[1 2]
#  [3 4]
#  [5 6]], shape=(3, 2), dtype=int32)
# tf.Tensor([1 2], shape=(2,), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor([1 3 5], shape=(3,), dtype=int32)
# 2026-07-03 18:20:43.897640: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-07-03 18:20:43.923011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-07-03 18:20:43.923404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
