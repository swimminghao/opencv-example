# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 加这一行屏蔽提示

import tensorflow as tf

data1 = tf.constant([[6, 6]])
data2 = tf.constant([[2], [2]])
data3 = tf.constant([[3, 3]])

matMul = tf.matmul(data1, data2)
matMul2 = tf.multiply(data1, data2)
matAdd = tf.add(data1, data3)

print("matMul:", matMul.numpy())       # [[24]]
print("matMul2:", matMul2.numpy())     # [[12 12], [12 12]]
print("matAdd:", matAdd.numpy())       # [[9 9]]

# %%
import tensorflow as tf
print(tf.reduce_sum(tf.constant([1,2,3])))
# Out:
# 2026-07-03 18:25:22.501386: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
