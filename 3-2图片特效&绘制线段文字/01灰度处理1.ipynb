# %%
#imread 
#方法1 imread 
import cv2
img0 = cv2.imread('/Users/xh/workspaces/jupyter/opencv-example/2入门/opencv入门/image0.JPG', 0)
img1 = cv2.imread('/Users/xh/workspaces/jupyter/opencv-example/2入门/opencv入门/image0.JPG', 1)
print(img0.shape)
print(img1.shape)
cv2.imshow('img',img0)
cv2.waitKey(0)
import matplotlib.pyplot as plt
img_rgb = cv2.cvtColor(img0, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('Image')
plt.axis('off')
plt.show()
# Out:
# (547, 730)
# (547, 730, 3)

# %%
#方法2 cvtColor
import cv2
img = cv2.imread('/Users/xh/workspaces/jupyter/opencv-example/2入门/opencv入门/image0.JPG', 1)
dst = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)# 颜色空间转换 1 data 2 BGR gray
import matplotlib.pyplot as plt
img_rgb = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('Image')
plt.axis('off')
plt.show()
